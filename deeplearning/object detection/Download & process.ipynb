# %%
<a href="https://colab.research.google.com/github/Joshuajee/AI-ML-PROJECTS/blob/master/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download and process images

# %%
import os
from googledriver import download_folder
from PIL import Image
from pillow_heif import register_heif_opener

# %%
url = "https://drive.google.com/drive/folders/1x6vDLMmmc1In5g9isOK9q1XLlg2-efuf?usp=drive_link"
output_path = "images" 

download_folder(url, output_path)
# Out:
# ['images/Copy of IMG_2488.heic',
#  'images/IMG_2378.heic',
#  'images/IMG_2379.heic',
#  'images/IMG_2451.heic',
#  'images/IMG_2452.heic',
#  'images/IMG_2453.heic',
#  'images/IMG_2454.heic',
#  'images/IMG_2489.heic',
#  'images/IMG_2495.heic',
#  'images/IMG_2498.heic',
#  'images/IMG_2499.heic',
#  'images/IMG_2500.heic',
#  'images/IMG_2501.heic',
#  'images/IMG_2508.HEIC',
#  'images/IMG_2548.HEIC',
#  'images/IMG_2553.HEIC',
#  'images/IMG_2733.HEIC',
#  'images/IMG_2733.HEIF.heic',
#  'images/IMG_2733.HEIF.heic',
#  'images/IMG_2735.HEIC',
#  'images/IMG_2735.HEIC',
#  'images/IMG_2735.HEIC',
#  'images/IMG_2736.HEIC',
#  'images/IMG_2736.HEIC',
#  'images/IMG_2736.HEIC',
#  'images/IMG_2746.HEIC',
#  'images/IMG_2747.HEIC',
#  'images/IMG_2748.HEIC',
#  'images/IMG_2756.HEIC',
#  'images/IMG_2767.HEIC',
#  'images/IMG_2768.HEIC',
#  'images/IMG_2776.HEIC',
#  'images/IMG_2776.HEIC',
#  'images/IMG_2777.HEIC',
#  'images/IMG_2777.HEIC',
#  'images/IMG_2778.heic',
#  'images/IMG_2778.heic',
#  'images/IMG_2779.heic',
#  'images/IMG_2779.heic',
#  'images/IMG_2780.heic',
#  'images/IMG_2780.heic',
#  'images/IMG_2781.heic',
#  'images/IMG_2781.heic',
#  'images/IMG_2782.heic',
#  'images/IMG_2782.heic',
#  'images/IMG_2783.heic',
#  'images/IMG_2783.heic',
#  'images/IMG_2784.heic',
#  'images/IMG_2784.heic',
#  'images/IMG_2785.heic']

# %%
register_heif_opener()

def convert_and_reduce_quality(heic_path, jpeg_path, quality_percentage=60):
    """
    Converts a single HEIC file to JPEG and reduces the quality/size.
    """
    try:
        img = Image.open(heic_path)
        if img.mode != 'RGB':
            img = img.convert('RGB')

        img.save(jpeg_path, format='JPEG', quality=quality_percentage)
        
        print(f"Successfully converted and saved to {jpeg_path} with quality: {quality_percentage}%")

    except Exception as e:
        print(f"An error occurred: {e}")

def get_image_list():
    directory_path = './images/'
    all_entries = os.listdir(directory_path)
    return [entry for entry in all_entries if entry.lower().endswith(".heic")]

# %%
try:
    os.mkdir(f"./data/")
except:
    pass # donot
images = get_image_list()
total_images = len(images)
for i, image in enumerate(images):
    convert_and_reduce_quality(f"./images/{image}", f"./data/{image[:-5]}.jpg", 10)
    percentage = ((i + 1) * 100 / total_images)
    print(f"Percentage: {round(percentage, 2)} %")
# Out:
# Successfully converted and saved to ./data/IMG_2781.jpg with quality: 10%
# Percentage: 1.85 %
# Successfully converted and saved to ./data/IMG_2451.jpg with quality: 10%
# Percentage: 3.7 %
# Successfully converted and saved to ./data/IMG_2797.jpg with quality: 10%
# Percentage: 5.56 %
# Successfully converted and saved to ./data/IMG_2778.jpg with quality: 10%
# Percentage: 7.41 %
# Successfully converted and saved to ./data/IMG_2735.jpg with quality: 10%
# Percentage: 9.26 %
# Successfully converted and saved to ./data/IMG_2489.jpg with quality: 10%
# Percentage: 11.11 %
# Successfully converted and saved to ./data/IMG_2796.jpg with quality: 10%
# Percentage: 12.96 %
# Successfully converted and saved to ./data/IMG_2779.jpg with quality: 10%
# Percentage: 14.81 %
# Successfully converted and saved to ./data/IMG_2780.jpg with quality: 10%
# Percentage: 16.67 %
# Successfully converted and saved to ./data/IMG_2498.jpg with quality: 10%
# Percentage: 18.52 %
# Successfully converted and saved to ./data/IMG_2733.HEIF.jpg with quality: 10%
# Percentage: 20.37 %
# Successfully converted and saved to ./data/IMG_2748.jpg with quality: 10%
# Percentage: 22.22 %
# Successfully converted and saved to ./data/IMG_2508.jpg with quality: 10%
# Percentage: 24.07 %
# Successfully converted and saved to ./data/IMG_2733.jpg with quality: 10%
# Percentage: 25.93 %
# Successfully converted and saved to ./data/IMG_2787.jpg with quality: 10%
# Percentage: 27.78 %
# Successfully converted and saved to ./data/IMG_2768.jpg with quality: 10%
# Percentage: 29.63 %
# Successfully converted and saved to ./data/IMG_2553.jpg with quality: 10%
# Percentage: 31.48 %
# Successfully converted and saved to ./data/IMG_2800.jpg with quality: 10%
# Percentage: 33.33 %
# Successfully converted and saved to ./data/IMG_2379.jpg with quality: 10%
# Percentage: 35.19 %
# Successfully converted and saved to ./data/IMG_2791.jpg with quality: 10%
# Percentage: 37.04 %
# Successfully converted and saved to ./data/IMG_2790.jpg with quality: 10%
# Percentage: 38.89 %
# Successfully converted and saved to ./data/IMG_2378.jpg with quality: 10%
# Percentage: 40.74 %
# Successfully converted and saved to ./data/IMG_2801.jpg with quality: 10%
# Percentage: 42.59 %
# Successfully converted and saved to ./data/IMG_2786.jpg with quality: 10%
# Percentage: 44.44 %
# Successfully converted and saved to ./data/IMG_2495.jpg with quality: 10%
# Percentage: 46.3 %
# Successfully converted and saved to ./data/IMG_2548.jpg with quality: 10%
# Percentage: 48.15 %
# Successfully converted and saved to ./data/IMG_2499.jpg with quality: 10%
# Percentage: 50.0 %
# Successfully converted and saved to ./data/IMG_2789.jpg with quality: 10%
# Percentage: 51.85 %
# Successfully converted and saved to ./data/IMG_2793.jpg with quality: 10%
# Percentage: 53.7 %
# Successfully converted and saved to ./data/IMG_2802.jpg with quality: 10%
# Percentage: 55.56 %
# Successfully converted and saved to ./data/IMG_2785.jpg with quality: 10%
# Percentage: 57.41 %
# Successfully converted and saved to ./data/IMG_2746.jpg with quality: 10%
# Percentage: 59.26 %
# Successfully converted and saved to ./data/IMG_2747.jpg with quality: 10%
# Percentage: 61.11 %
# Successfully converted and saved to ./data/IMG_2784.jpg with quality: 10%
# Percentage: 62.96 %
# Successfully converted and saved to ./data/IMG_2803.jpg with quality: 10%
# Percentage: 64.81 %
# Successfully converted and saved to ./data/IMG_2454.jpg with quality: 10%
# Percentage: 66.67 %
# Successfully converted and saved to ./data/IMG_2792.jpg with quality: 10%
# Percentage: 68.52 %
# Successfully converted and saved to ./data/IMG_2767.jpg with quality: 10%
# Percentage: 70.37 %
# Successfully converted and saved to ./data/IMG_2788.jpg with quality: 10%
# Percentage: 72.22 %
# Successfully converted and saved to ./data/IMG_2795.jpg with quality: 10%
# Percentage: 74.07 %
# Successfully converted and saved to ./data/IMG_2453.jpg with quality: 10%
# Percentage: 75.93 %
# Successfully converted and saved to ./data/IMG_2783.jpg with quality: 10%
# Percentage: 77.78 %
# Successfully converted and saved to ./data/IMG_2500.jpg with quality: 10%
# Percentage: 79.63 %
# Successfully converted and saved to ./data/IMG_2756.jpg with quality: 10%
# Percentage: 81.48 %
# Successfully converted and saved to ./data/IMG_2776.jpg with quality: 10%
# Percentage: 83.33 %
# Successfully converted and saved to ./data/IMG_2799.jpg with quality: 10%
# Percentage: 85.19 %
# Successfully converted and saved to ./data/IMG_2736.jpg with quality: 10%
# Percentage: 87.04 %
# Successfully converted and saved to ./data/IMG_2777.jpg with quality: 10%
# Percentage: 88.89 %
# Successfully converted and saved to ./data/IMG_2798.jpg with quality: 10%
# Percentage: 90.74 %
# Successfully converted and saved to ./data/Copy of IMG_2488.jpg with quality: 10%
# Percentage: 92.59 %
# Successfully converted and saved to ./data/IMG_2501.jpg with quality: 10%
# Percentage: 94.44 %
# Successfully converted and saved to ./data/IMG_2782.jpg with quality: 10%
# Percentage: 96.3 %
# Successfully converted and saved to ./data/IMG_2452.jpg with quality: 10%
# Percentage: 98.15 %
# Successfully converted and saved to ./data/IMG_2794.jpg with quality: 10%
# Percentage: 100.0 %
